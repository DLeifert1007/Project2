# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
# import data
df = pd.read_csv('sports_management_dataset.csv')
df.head(10)
# Out:
#   Energy Consumption Carbon Emissions Waste Generation Community Engagement  \
# 0           Moderate             High             High  Moderate Engagement
# 1               High         Moderate             High  Moderate Engagement
# 2               High             High             High       Low Engagement
# 3               High             High             High  Moderate Engagement
# 4           Moderate             High              Low       Low Engagement
# 5           Moderate         Moderate             High  Moderate Engagement
# 6                Low             High         Moderate  Moderate Engagement
# 7               High             High         Moderate      High Engagement
# 8               High             High         Moderate      High Engagement
# 9               High             High             High  Moderate Engagement
#
#   Volunteer Participation    Health Impact Water Usage  \
# 0                Moderate  Moderate Impact    Moderate
# 1                     Low       Low Impact    Moderate
# 2                    High  Moderate Impact    Moderate
# 3                Moderate  Moderate Impact    Moderate
# 4                     Low  Moderate Impact        High
# 5                    High       Low Impact    Moderate
# 6                     Low  Moderate Impact    Moderate
# 7                     Low      High Impact         Low
# 8                Moderate      High Impact         Low
# 9                    High  Moderate Impact         Low
#
#   Material Recycling Rate Operational Cost Efficiency Event Scale  \
# 0                Moderate             High Efficiency       Local
# 1                     Low         Moderate Efficiency    National
# 2                Moderate         Moderate Efficiency    National
# 3                Moderate         Moderate Efficiency    Regional
# 4                    High             High Efficiency    Regional
# 5                     Low         Moderate Efficiency    Regional
# 6                Moderate             High Efficiency    Regional
# 7                     Low             High Efficiency    National
# 8                     Low         Moderate Efficiency       Local
# 9                     Low             High Efficiency       Local
#
#              Event Focus Sustainability Score  Social Impact Level  \
# 0  Community Development                  Low      High Engagement
# 1  Community Development             Moderate       Low Engagement
# 2  Community Development                 High       Low Engagement
# 3  Community Development                 High       Low Engagement
# 4  Community Development                  Low  Moderate Engagement
# 5  Community Development                 High       Low Engagement
# 6          Youth-Focused                 High  Moderate Engagement
# 7  Community Development             Moderate      High Engagement
# 8  Community Development             Moderate       Low Engagement
# 9           Recreational                  Low  Moderate Engagement
#
#    Resource Efficiency Event Type Classification
# 0  Moderate Efficiency           Health-Oriented
# 1  Moderate Efficiency              Recreational
# 2      High Efficiency              Recreational
# 3      High Efficiency              Recreational
# 4  Moderate Efficiency     Community Development
# 5  Moderate Efficiency     Community Development
# 6  Moderate Efficiency             Youth-Focused
# 7       Low Efficiency              Recreational
# 8       Low Efficiency             Youth-Focused
# 9  Moderate Efficiency     Community Development

# %%
df['Energy Consumption'].str.split().str[0]
# Out:
# 0         Moderate
# 1             High
# 2             High
# 3             High
# 4         Moderate
#             ...
# 101995        High
# 101996    Moderate
# 101997    Moderate
# 101998         Low
# 101999        High
# Name: Energy Consumption, Length: 102000, dtype: object

# %%
# create a list of columns to change
cols = ['Community Engagement', 'Health Impact', 'Operational Cost Efficiency', 'Social Impact Level', 'Resource Efficiency']

# loop through the columns and remove the second word
for col in cols:
    df[col] = df[col].str.split().str[0]

df.head()
# Out:
#   Energy Consumption Carbon Emissions Waste Generation Community Engagement  \
# 0           Moderate             High             High             Moderate
# 1               High         Moderate             High             Moderate
# 2               High             High             High                  Low
# 3               High             High             High             Moderate
# 4           Moderate             High              Low                  Low
#
#   Volunteer Participation Health Impact Water Usage Material Recycling Rate  \
# 0                Moderate      Moderate    Moderate                Moderate
# 1                     Low           Low    Moderate                     Low
# 2                    High      Moderate    Moderate                Moderate
# 3                Moderate      Moderate    Moderate                Moderate
# 4                     Low      Moderate        High                    High
#
#   Operational Cost Efficiency Event Scale            Event Focus  \
# 0                        High       Local  Community Development
# 1                    Moderate    National  Community Development
# 2                    Moderate    National  Community Development
# 3                    Moderate    Regional  Community Development
# 4                        High    Regional  Community Development
#
#   Sustainability Score Social Impact Level Resource Efficiency  \
# 0                  Low                High            Moderate
# 1             Moderate                 Low            Moderate
# 2                 High                 Low                High
# 3                 High                 Low                High
# 4                  Low            Moderate            Moderate
#
#   Event Type Classification
# 0           Health-Oriented
# 1              Recreational
# 2              Recreational
# 3              Recreational
# 4     Community Development

# %%
# define X and y variables
X= df.drop(columns = 'Sustainability Score')
y = df['Sustainability Score'].values.reshape(-1,1)

# split dataset in to train and test data 
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state= 1)
X_train.head()
# Out:
#       Energy Consumption Carbon Emissions Waste Generation  \
# 23375               High         Moderate         Moderate
# 86945                Low             High         Moderate
# 7149                High             High              Low
# 85760           Moderate             High             High
# 37809               High             High             High
#
#       Community Engagement Volunteer Participation Health Impact Water Usage  \
# 23375                 High                     Low          High         Low
# 86945                  Low                     Low      Moderate        High
# 7149              Moderate                     Low           Low    Moderate
# 85760                  Low                     Low      Moderate        High
# 37809                  Low                     Low      Moderate    Moderate
#
#       Material Recycling Rate Operational Cost Efficiency Event Scale  \
# 23375                Moderate                        High    Regional
# 86945                Moderate                         Low    Regional
# 7149                      Low                         Low    Regional
# 85760                Moderate                    Moderate       Local
# 37809                     Low                    Moderate       Local
#
#                  Event Focus Social Impact Level Resource Efficiency  \
# 23375          Youth-Focused                High            Moderate
# 86945  Community Development            Moderate                High
# 7149   Community Development                 Low                 Low
# 85760  Community Development                 Low            Moderate
# 37809          Youth-Focused            Moderate            Moderate
#
#       Event Type Classification
# 23375     Community Development
# 86945             Youth-Focused
# 7149      Community Development
# 85760     Community Development
# 37809     Community Development

# %%
# create a list of columns to encode
ordinal_cols = ['Energy Consumption', 'Carbon Emissions', 'Waste Generation', 'Community Engagement', 
               'Volunteer Participation', 'Health Impact', 'Water Usage', 'Material Recycling Rate', 
               'Operational Cost Efficiency','Social Impact Level', 'Resource Efficiency']


ordinal_encoder =OrdinalEncoder(categories=[['Low', 'Moderate', 'High']], handle_unknown='use_encoded_value', unknown_value=-1)


X_train_ordinal = X_train[ordinal_cols]
X_test_ordinal = X_test[ordinal_cols]


for col in ordinal_cols:
    X_train_ordinal[[col]] = ordinal_encoder.fit_transform(X_train[[col]])
    X_test_ordinal[[col]] = ordinal_encoder.transform(X_test[[col]])
# Out:
# C:\Users\linan\AppData\Local\Temp\ipykernel_11408\3216963088.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_ordinal[[col]] = ordinal_encoder.fit_transform(X_train[[col]])
# C:\Users\linan\AppData\Local\Temp\ipykernel_11408\3216963088.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_ordinal[[col]] = ordinal_encoder.transform(X_test[[col]])
# C:\Users\linan\AppData\Local\Temp\ipykernel_11408\3216963088.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_ordinal[[col]] = ordinal_encoder.fit_transform(X_train[[col]])
# C:\Users\linan\AppData\Local\Temp\ipykernel_11408\3216963088.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_ordinal[[col]] = ordinal_encoder.transform(X_test[[col]])
# C:\Users\linan\AppData\Local\Temp\ipykernel_11408\3216963088.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_ordinal[[col]] = ordinal_encoder.fit_transform(X_train[[col]])
# C:\Users\linan\AppData\Local\Temp\ipykernel_11408\3216963088.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_ordinal[[col]] = ordinal_encoder.transform(X_test[[col]])
# C:\Users\linan\AppData\Local\Temp\ipykernel_11408\3216963088.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_ordinal[[col]] = ordinal_encoder.fit_transform(X_train[[col]])
# C:\Users\linan\AppData\Local\Temp\ipykernel_11408\3216963088.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_ordinal[[col]] = ordinal_encoder.transform(X_test[[col]])
# C:\Users\linan\AppData\Local\Temp\ipykernel_11408\3216963088.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_ordinal[[col]] = ordinal_encoder.fit_transform(X_train[[col]])
# C:\Users\linan\AppData\Local\Temp\ipykernel_11408\3216963088.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_ordinal[[col]] = ordinal_encoder.transform(X_test[[col]])
# C:\Users\linan\AppData\Local\Temp\ipykernel_11408\3216963088.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_ordinal[[col]] = ordinal_encoder.fit_transform(X_train[[col]])
# C:\Users\linan\AppData\Local\Temp\ipykernel_11408\3216963088.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_ordinal[[col]] = ordinal_encoder.transform(X_test[[col]])
# C:\Users\linan\AppData\Local\Temp\ipykernel_11408\3216963088.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_ordinal[[col]] = ordinal_encoder.fit_transform(X_train[[col]])
# C:\Users\linan\AppData\Local\Temp\ipykernel_11408\3216963088.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_ordinal[[col]] = ordinal_encoder.transform(X_test[[col]])
# C:\Users\linan\AppData\Local\Temp\ipykernel_11408\3216963088.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_ordinal[[col]] = ordinal_encoder.fit_transform(X_train[[col]])
# C:\Users\linan\AppData\Local\Temp\ipykernel_11408\3216963088.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_ordinal[[col]] = ordinal_encoder.transform(X_test[[col]])
# C:\Users\linan\AppData\Local\Temp\ipykernel_11408\3216963088.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_ordinal[[col]] = ordinal_encoder.fit_transform(X_train[[col]])
# C:\Users\linan\AppData\Local\Temp\ipykernel_11408\3216963088.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_ordinal[[col]] = ordinal_encoder.transform(X_test[[col]])
# C:\Users\linan\AppData\Local\Temp\ipykernel_11408\3216963088.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_ordinal[[col]] = ordinal_encoder.fit_transform(X_train[[col]])
# C:\Users\linan\AppData\Local\Temp\ipykernel_11408\3216963088.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_ordinal[[col]] = ordinal_encoder.transform(X_test[[col]])
# C:\Users\linan\AppData\Local\Temp\ipykernel_11408\3216963088.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_ordinal[[col]] = ordinal_encoder.fit_transform(X_train[[col]])
# C:\Users\linan\AppData\Local\Temp\ipykernel_11408\3216963088.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_ordinal[[col]] = ordinal_encoder.transform(X_test[[col]])

# %%
# create a list of columns to encode using one-hot encoding
nominal_cols = ['Event Scale', 'Event Focus', 'Event Type Classification']

# create a loop to encode the data
one_hot_encoder = OneHotEncoder(drop= 'first', handle_unknown='ignore', sparse_output=False)

# Fit the encoder to the data
one_hot_encoder.fit(X_train[nominal_cols])

# Transform the data
X_train_nominal_col = one_hot_encoder.transform(X_train[nominal_cols])

# Default output is sparse matrix
# encoded_data

# # Get new feature names
one_hot_encoder.get_feature_names_out()

# # Set up the OneHotEncoder so it will transform to Pandas
one_hot_encoder.set_output(transform="pandas")

# # Fit and transform the OneHotEncoder to the columns to encode
X_train_nominal_col = one_hot_encoder.fit_transform(X_train[nominal_cols])
X_test_nominal_col = one_hot_encoder.transform(X_test[nominal_cols])
X_train_nominal_col.head()
# Out:
#        Event Scale_National  Event Scale_Regional  \
# 23375                   0.0                   1.0
# 86945                   0.0                   1.0
# 7149                    0.0                   1.0
# 85760                   0.0                   0.0
# 37809                   0.0                   0.0
#
#        Event Focus_Health-Oriented  Event Focus_Recreational  \
# 23375                          0.0                       0.0
# 86945                          0.0                       0.0
# 7149                           0.0                       0.0
# 85760                          0.0                       0.0
# 37809                          0.0                       0.0
#
#        Event Focus_Youth-Focused  Event Type Classification_Health-Oriented  \
# 23375                        1.0                                        0.0
# 86945                        0.0                                        0.0
# 7149                         0.0                                        0.0
# 85760                        0.0                                        0.0
# 37809                        1.0                                        0.0
#
#        Event Type Classification_Recreational  \
# 23375                                     0.0
# 86945                                     0.0
# 7149                                      0.0
# 85760                                     0.0
# 37809                                     0.0
#
#        Event Type Classification_Youth-Focused
# 23375                                      0.0
# 86945                                      1.0
# 7149                                       0.0
# 85760                                      0.0
# 37809                                      0.0

# %%
# combine the encoded data with the original data
X_train= pd.concat([X_train_ordinal, X_train_nominal_col], axis=1)
X_train.head()
# Out:
#        Energy Consumption  Carbon Emissions  Waste Generation  \
# 23375                 2.0               1.0               1.0
# 86945                 0.0               2.0               1.0
# 7149                  2.0               2.0               0.0
# 85760                 1.0               2.0               2.0
# 37809                 2.0               2.0               2.0
#
#        Community Engagement  Volunteer Participation  Health Impact  \
# 23375                   2.0                      0.0            2.0
# 86945                   0.0                      0.0            1.0
# 7149                    1.0                      0.0            0.0
# 85760                   0.0                      0.0            1.0
# 37809                   0.0                      0.0            1.0
#
#        Water Usage  Material Recycling Rate  Operational Cost Efficiency  \
# 23375          0.0                      1.0                          2.0
# 86945          2.0                      1.0                          0.0
# 7149           1.0                      0.0                          0.0
# 85760          2.0                      1.0                          1.0
# 37809          1.0                      0.0                          1.0
#
#        Social Impact Level  Resource Efficiency  Event Scale_National  \
# 23375                  2.0                  1.0                   0.0
# 86945                  1.0                  2.0                   0.0
# 7149                   0.0                  0.0                   0.0
# 85760                  0.0                  1.0                   0.0
# 37809                  1.0                  1.0                   0.0
#
#        Event Scale_Regional  Event Focus_Health-Oriented  \
# 23375                   1.0                          0.0
# 86945                   1.0                          0.0
# 7149                    1.0                          0.0
# 85760                   0.0                          0.0
# 37809                   0.0                          0.0
#
#        Event Focus_Recreational  Event Focus_Youth-Focused  \
# 23375                       0.0                        1.0
# 86945                       0.0                        0.0
# 7149                        0.0                        0.0
# 85760                       0.0                        0.0
# 37809                       0.0                        1.0
#
#        Event Type Classification_Health-Oriented  \
# 23375                                        0.0
# 86945                                        0.0
# 7149                                         0.0
# 85760                                        0.0
# 37809                                        0.0
#
#        Event Type Classification_Recreational  \
# 23375                                     0.0
# 86945                                     0.0
# 7149                                      0.0
# 85760                                     0.0
# 37809                                     0.0
#
#        Event Type Classification_Youth-Focused
# 23375                                      0.0
# 86945                                      1.0
# 7149                                       0.0
# 85760                                      0.0
# 37809                                      0.0

# %%
X_test= pd.concat([X_test_ordinal, X_test_nominal_col], axis=1)
X_test
# Out:
#        Energy Consumption  Carbon Emissions  Waste Generation  \
# 65226                 2.0               1.0               2.0
# 65591                 2.0               2.0               2.0
# 70106                 2.0               2.0               2.0
# 84400                 2.0               2.0               2.0
# 40117                 2.0               2.0               2.0
# ...                   ...               ...               ...
# 33584                 2.0               2.0               2.0
# 8370                  1.0               2.0               1.0
# 42484                 2.0               2.0               0.0
# 45090                 1.0               2.0               2.0
# 67329                 1.0               2.0               1.0
#
#        Community Engagement  Volunteer Participation  Health Impact  \
# 65226                   1.0                      2.0            2.0
# 65591                   1.0                      0.0            2.0
# 70106                   1.0                      0.0            0.0
# 84400                   1.0                      0.0            1.0
# 40117                   0.0                      0.0            0.0
# ...                     ...                      ...            ...
# 33584                   0.0                      0.0            1.0
# 8370                    1.0                      2.0            0.0
# 42484                   2.0                      0.0            0.0
# 45090                   0.0                      0.0            2.0
# 67329                   0.0                      2.0            1.0
#
#        Water Usage  Material Recycling Rate  Operational Cost Efficiency  \
# 65226          0.0                      1.0                          0.0
# 65591          2.0                      1.0                          2.0
# 70106          1.0                      2.0                          1.0
# 84400          1.0                      0.0                          1.0
# 40117          2.0                      1.0                          1.0
# ...            ...                      ...                          ...
# 33584          0.0                      0.0                          1.0
# 8370           1.0                      1.0                          1.0
# 42484          1.0                      2.0                          0.0
# 45090          1.0                      1.0                          0.0
# 67329          1.0                      1.0                          0.0
#
#        Social Impact Level  Resource Efficiency  Event Scale_National  \
# 65226                  2.0                  0.0                   0.0
# 65591                  2.0                  0.0                   0.0
# 70106                  2.0                  1.0                   1.0
# 84400                  0.0                  1.0                   0.0
# 40117                  0.0                  0.0                   1.0
# ...                    ...                  ...                   ...
# 33584                  0.0                  1.0                   0.0
# 8370                   0.0                  1.0                   1.0
# 42484                  0.0                  1.0                   1.0
# 45090                  2.0                  2.0                   0.0
# 67329                  2.0                  0.0                   0.0
#
#        Event Scale_Regional  Event Focus_Health-Oriented  \
# 65226                   1.0                          0.0
# 65591                   0.0                          0.0
# 70106                   0.0                          0.0
# 84400                   0.0                          0.0
# 40117                   0.0                          0.0
# ...                     ...                          ...
# 33584                   1.0                          0.0
# 8370                    0.0                          0.0
# 42484                   0.0                          1.0
# 45090                   1.0                          0.0
# 67329                   0.0                          1.0
#
#        Event Focus_Recreational  Event Focus_Youth-Focused  \
# 65226                       0.0                        1.0
# 65591                       0.0                        0.0
# 70106                       0.0                        0.0
# 84400                       0.0                        0.0
# 40117                       1.0                        0.0
# ...                         ...                        ...
# 33584                       0.0                        0.0
# 8370                        0.0                        1.0
# 42484                       0.0                        0.0
# 45090                       1.0                        0.0
# 67329                       0.0                        0.0
#
#        Event Type Classification_Health-Oriented  \
# 65226                                        0.0
# 65591                                        0.0
# 70106                                        0.0
# 84400                                        0.0
# 40117                                        1.0
# ...                                          ...
# 33584                                        0.0
# 8370                                         0.0
# 42484                                        0.0
# 45090                                        0.0
# 67329                                        0.0
#
#        Event Type Classification_Recreational  \
# 65226                                     0.0
# 65591                                     0.0
# 70106                                     0.0
# 84400                                     0.0
# 40117                                     0.0
# ...                                       ...
# 33584                                     0.0
# 8370                                      1.0
# 42484                                     0.0
# 45090                                     0.0
# 67329                                     0.0
#
#        Event Type Classification_Youth-Focused
# 65226                                      0.0
# 65591                                      1.0
# 70106                                      0.0
# 84400                                      0.0
# 40117                                      0.0
# ...                                        ...
# 33584                                      0.0
# 8370                                       0.0
# 42484                                      0.0
# 45090                                      1.0
# 67329                                      1.0
#
# [25500 rows x 19 columns]

# %%
# create an instance of the OrdinalEncoder and fit transform the y_train
# transform the y_test
ord_enc_y = OrdinalEncoder(categories=[['Low', 'Moderate', 'High']], handle_unknown='use_encoded_value', unknown_value=-1)

y_train = np.ravel(ord_enc_y.fit_transform(y_train))
y_test= np.ravel(ord_enc_y.transform(y_test))

# %%
from sklearn.ensemble import GradientBoostingClassifier
# Train the Gradient Boosting classifier
clf1 = GradientBoostingClassifier(random_state=1).fit(X_train, y_train)

# Evaluate the model
print(f'Training Score: {clf1.score(X_train, y_train)}')
print(f'Testing Score: {clf1.score(X_test, y_test)}')
# Out:
# Training Score: 0.49658823529411766
# Testing Score: 0.4983529411764706
